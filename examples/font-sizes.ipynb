# %%
from tueplots import fontsizes, figsize
import matplotlib.pyplot as plt
import matplotlib as mpl

# %% [markdown]
# Fontsizes are dictionaries that can be passed to `matplotlib.pyplot.rcParams.update()`.

# %%
fontsizes.icml2022()
# Out:
# {'axes.labelsize': 9,
#  'font.size': 9,
#  'legend.fontsize': 7,
#  'xtick.labelsize': 7,
#  'ytick.labelsize': 7,
#  'axes.titlesize': 'medium'}

# %% [markdown]
# Compare the default font-sizes to, e.g., the ICML style. (To make differences more obvious, we increase the `dpi` value.)

# %%
plt.rcParams.update(figsize.icml2022())  # see the font-size in context
fig, ax = plt.subplots(dpi=120)
ax.plot([1.0, 2.0], [3.0, 4.0])
ax.set_title("Title")
ax.set_xlabel("xlabel")
ax.set_ylabel("ylabel")
plt.show()

# %%
plt.rcParams.update(fontsizes.icml2022())
fig, ax = plt.subplots(dpi=120)
ax.plot([1.0, 2.0], [3.0, 4.0])
ax.set_title("Title")
ax.set_xlabel("xlabel")
ax.set_ylabel("ylabel")

plt.show()

# %%
plt.rcParams.update(fontsizes.neurips2021())
fig, ax = plt.subplots(dpi=120)
ax.plot([1.0, 2.0], [3.0, 4.0])
ax.set_title("Title")
ax.set_xlabel("xlabel")
ax.set_ylabel("ylabel")

plt.show()
